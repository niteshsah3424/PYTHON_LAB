# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshsah3424/PYTHON_LAB/blob/main/1_week_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
# print the hello world
a=input(print("enter the hello world"))
print(a)
# Out:
# enter the hello world
# Nonehello world
# hello world

# %%
# wap to print the sum of the two elements
a=int(input("enter the first number"))
b= int(input("enter the second number"))

sum=a+b
print("sum",sum)
# Out:
# enter the first number5
# enter the second number4
# sum 9

# %%
# wap to find the even and odd
num=int(input("enter the number"))

if num % 2==0:
 print("the number is even",num)
else:
  print("the number is odd",num)
# Out:
# enter the number-9
# the number is odd -9

# %%
# wap to find the positive negative and zero

num =int(input("enter the number"))
if num>0:
  print("the number is positive",num)

elif num==0:
  print("the number is zero",num)

else:
  print("the number is negative",num)
# Out:
# enter the number0
# the number is zero 0

# %%
#wap to find the largest of three element
a=int(input("enter the first element"))
b=int(input("enter the second element"))
c=int(input("enter the third element"))

if a>b and a>c:
  print(a, "is the largest")

elif b>a and b>c:
  print(b,"is the largest")

else:
  print(c,"is the largest")
# Out:
# enter the first element78
# enter the second element6
# enter the third element5
# 78 is the largest

# %%
#check if number is divisible by 5 or not
num= int(input("enter the number"))

if num%5==0:
  print(num,"the number is divisible by 5")

else:
  print(num,"the number is not divisible by 5")
# Out:
# enter the number15
# 15 the number is divisible by 5

# %%
# check if the number is divisible by 5 and 3 or not
num=int(input("enter the number "))

if num % 5==0 and num%3==0:
  print(num,"is divisible by 5 and 3 ")

else:
  print(num," is not divisible by 5 and 3")
# Out:
# enter the number 15
# 15 is divisible by 5 and 3

# %%
# check if a year is leap year or not
year=int(input("enter the year "))

if year%4==0 or year%400==0:
  print(year,"is the leap year")

elif year%100==0:
  print(year,"is not a leap year")

else:
  print(year,"is not a leap year")
# Out:
# enter the year 2024
# 2024 is the leap year
