# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshsah3424/PYTHON_LAB/blob/main/4_week_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Weighted graph using adjacency list

# %%
graph = {
    'A': [('B', 1), ('C', 4)],
    'B': [('A', 1), ('C', 2), ('D', 5)],
    'C': [('A', 4), ('B', 2), ('D', 1)],
    'D': [('B', 5), ('C', 1)]
}

# %%
import heapq

def uniform_cost_search(graph, start, goal):
    pq = [(0, start, [])]
    visited = set()

    while pq:
        cost, node, path = heapq.heappop(pq)

        if node in visited:
            continue

        visited.add(node)
        path = path + [node]

        if node == goal:
            return cost, path

        for neighbor, edge_cost in graph[node]:
            if neighbor not in visited:
                heapq.heappush(pq, (cost + edge_cost, neighbor, path))

    return float('inf'), []

# %%
start_node = 'A'
goal_node = 'D'

cost, path = uniform_cost_search(graph, start_node, goal_node)

print("Uniform Cost Search Result")
print("Minimum Cost:", cost)
print("Optimal Path:", path)
# Out:
# Uniform Cost Search Result
# Minimum Cost: 4
# Optimal Path: ['A', 'B', 'C', 'D']

# %%
#BFS-unweighted

# %%
from collections import deque

def bfs(graph, start, goal):
    queue = deque([(start, [start])])
    visited = set([start])

    while queue:
        node, path = queue.popleft()

        if node == goal:
            return path

        for neighbor, _ in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append((neighbor, path + [neighbor]))

    return []

# %%
bfs_path = bfs(graph, start_node, goal_node)

print("BFS Result")
print("Path Found:", bfs_path)
# Out:
# BFS Result
# Path Found: ['A', 'B', 'D']
